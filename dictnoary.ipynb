# %%
d={"a":1,"b":2,"c":3}

# %%
d
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %%
d["a"]
# Out:
# 1

# %%
d["d"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 d["d"]
#
# KeyError: 'd'

# %%
d=dict(name="abc",age=25)

# %%
d
# Out:
# {'name': 'abc', 'age': 25}

# %%
d["name"]
# Out:
# 'abc'

# %%
d.get("sal",0)  #looks sal key not there return 0
# Out:
# 0

# %%
students={
    "name":"abc",
    "age":25,
    "city":"Pune"
}

# %%
#add element

students["salary"]=50000

# %%
students
# Out:
# {'name': 'vij', 'age': 25, 'city': 'Pune'}

# %%
students["name"]="vij" #update values

# %%
#Remove Values 
# del 
del students["salary"]

# %%
# pop
#popitem()
# clear

# %%
for k in students:
    print(k)
# Out:
# name
# age
# city

# %%
for v in students.values():
    print(v)
# Out:
# vij
# 25
# Pune

# %%
for k,v in students.items():
    print(k,v)
# Out:
# name vij
# age 25
# city Pune

# %%
d={"a":1,"b":2,"c":3}
print(d.keys())
print(d["a"])
# Out:
# dict_keys(['a', 'b', 'c'])
# 1

# %%
d={"a":1,"b":2,"c":3}
k=d.keys()
print("Before:",k )
d["city"]="Pune"
print("After:",k)
# Out:
# Before: dict_keys(['a', 'b', 'c'])
# After: dict_keys(['a', 'b', 'c', 'city'])

# %%
for key in d:
    print(key)
# Out:
# a
# b
# c
# city

# %%
for k in d.keys():
    print(k)
for v in d.values():
    print(v)    
for i,j in d.items():
    if 19==j:
        print(j)
# Out:
# a
# b
# c
# city
# 1
# 2
# 3
# Pune

# %%
print("csv" in d)
print("a" in d)
print(1 in d)
print(1 in d.values())
print(1 in d.items())
# Out:
# False
# True
# False
# True
# False

# %%
keys_list=list(d.keys())
print(keys_list)
# Out:
# ['a', 'b', 'c', 'city']

# %%
a=[1,2,3,4]
b=[3,4,5,6]
c=a-b
print(c)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[53], line 3
#       1 a=[1,2,3,4]
#       2 b=[3,4,5,6]
# ----> 3 c=a-b
#       4 print(c)
#
# TypeError: unsupported operand type(s) for -: 'list' and 'list'

# %%
record={"name":"abc","age":25,"city":"Pune"}
required_keys=["name","city","salary"]
missing=required_keys - record.keys()
print(type(required_keys))
print(missing)
# Out:
# <class 'list'>
# {'salary'}

# %%
d={"a":1,"b":2,"c":3}
v=d.values()
print(v)
# Out:
# dict_values([1, 2, 3])

# %%
d={"a":1,"b":2,"c":3}
k=d.values()
print("Before:",k )
d["city"]="Pune"
d["age"]=60
print("After:",k)
# Out:
# Before: dict_values([1, 2, 3])
# After: dict_values([1, 2, 3, 'Pune', 60])

# %%
for value in d.values():
    print(value)
# Out:
# 1
# 2
# 3
# Pune
# 60

# %%
valu=list(d.values())
print(valu)
# Out:
# [1, 2, 3, 'Pune', 60]

# %%
print(valu[0])
# Out:
# 1

# %%
sal={"A":40000,"B":50000,"C":60000,"D":70000,"E":80000}
print(sum(sal.values()))
# Out:
# 300000

# %%
status={"job1":"SUCCESS","job2":"FAILURE","job3":"SUCCESS","job4":"FAILURE"}
if "FAILURE" in status.values():
    print("Alert! There is a job failure.")
# Out:
# Alert! There is a job failure.

# %%
d={"name":"Raj","age":30,"city":"Pune"}
it=d.items()
print(it)
# Out:
# dict_items([('name', 'Raj'), ('age', 30), ('city', 'Pune')])

# %%
for k in d:
    print(k,d[k])
# Out:
# name Raj
# age 30
# city Pune

# %%
for k,v in d.items():
    print(k,v)
# Out:
# name Raj
# age 30
# city Pune

# %%
config={"host":"db","port":5432,"schema":"public"}
for k,v in config.items():
    print(f"{k}={v}")
# Out:
# host=db
# port=5432
# schema=public

# %%
d={"name":"Raj","age":30,"city":"Pune"}
print(d["city"])
# Out:
# Pune

# %%
d={"name":"Raj","age":30,"city":"Pune"}
print(d["sal"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[70], line 2
#       1 d={"name":"Raj","age":30,"city":"Pune"}
# ----> 2 print(d["sal"])
#
# KeyError: 'sal'

# %%
print(d.get("sal"))
# Out:
# None

# %%
logs=["A","B","A","C","A"]
freq={}
for x in logs:
    freq[x]=freq.get(x,0)+1
print(freq)
# Out:
# {'A': 3, 'B': 1, 'C': 1}

# %%
logs=["A","B","A","C","A"]
freq={}
for x in logs:
    freq[x]=freq.get(x,0)
    freq[x] +=1
print(freq)
# Out:
# {'A': 3, 'B': 1, 'C': 1}

# %%
freq={}
x="A"

# %%
freq[x] +=1
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[75], line 1
# ----> 1 freq[x] +=1
#
# KeyError: 'A'

# %%
d= {"A":3,"B":1,"C":1}
d.update({"C":31,"City":"Pune"})
print(d)
# Out:
# {'A': 3, 'B': 1, 'C': 31, 'City': 'Pune'}

# %%
c={"age":20}
c.setdefault("age",30)
# Out:
# 20

# %%
c
# Out:
# {'age': 20}

# %%
c.setdefault("age",35)
# Out:
# 20

# %%
c={"name":"vijay","age":25}
c.setdefault("g","m")
# Out:
# 'm'

# %%
print(c)
# Out:
# {'name': 'vijay', 'age': 25, 'g': 'm'}

# %%
c.get("g","f")
c.get("s","m")
# Out:
# 'm'

# %%
print(c)
# Out:
# {'name': 'vijay', 'age': 25, 'g': 'm'}
