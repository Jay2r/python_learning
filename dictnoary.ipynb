# %%
d={"a":1,"b":2,"c":3}

# %%
d
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %%
d["a"]
# Out:
# 1

# %%
d["d"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 d["d"]
#
# KeyError: 'd'

# %%
d=dict(name="abc",age=25)

# %%
d
# Out:
# {'name': 'abc', 'age': 25}

# %%
d["name"]
# Out:
# 'abc'

# %%
d.get("sal",0)  #looks sal key not there return 0
# Out:
# 0

# %%
students={
    "name":"abc",
    "age":25,
    "city":"Pune"
}

# %%
#add element

students["salary"]=50000

# %%
students
# Out:
# {'name': 'vij', 'age': 25, 'city': 'Pune'}

# %%
students["name"]="vij" #update values

# %%
#Remove Values 
# del 
del students["salary"]

# %%
# pop
#popitem()
# clear

# %%
for k in students:
    print(k)
# Out:
# name
# age
# city

# %%
for v in students.values():
    print(v)
# Out:
# vij
# 25
# Pune

# %%
for k,v in students.items():
    print(k,v)
# Out:
# name vij
# age 25
# city Pune
