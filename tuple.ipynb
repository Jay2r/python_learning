# %%
t=(10,20,30)
print(t)
#immutable and hashable
# Out:
# (10, 20, 30)

# %%
a=10,20,30
print(a)
print(type(a))
# Out:
# (10, 20, 30)
# <class 'tuple'>

# %%
t1=(5,)

# %%
print(type(t1))  #int
# Out:
# <class 'tuple'>

# %%
t=()

# %%
print(type(t))
# Out:
# <class 'tuple'>

# %%
t=(10)
print(type(t))
# Out:
# <class 'int'>

# %%
t=tuple([12,2,3,4,5])
print(t)
# Out:
# (12, 2, 3, 4, 5)

# %%
t2=tuple("hello")
print(t2)
# Out:
# ('h', 'e', 'l', 'l', 'o')

# %%
t=(10,20,30,40)
print(t[0]) #10
print(t[-1]) #40

print(t[1:3]) # (20,30)
print(t[:2]) # (10,20)
# Out:
# 10
# 40
# (20, 30)
# (10, 20)

# %%
t=(1,(5,6),3)

print(t[1][0])
# Out:
# 5

# %%
t=(10,20,30)
t[0] =99 # TypeError immutable

# %%
t=(1,[10,20],3)  #inner list is mutable
t[1].append(30)
print(t)
# Out:
# (1, [10, 20, 30], 3)

# %%
t=(1,(2,3),3)
t[1].append(30)
print(t)         #inner tuple is immutable and has no append for tupple
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 2
#       1 t=(1,(2,3),3)
# ----> 2 t[1].append(30)
#       3 print(t)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
# Tuple Operations 
#Concatenation 
(1,2)+(3,4)
# Out:
# (1, 2, 3, 4)

# %%
t=(1,2)
t=t+(10,)
print(t)
# Out:
# (1, 2, 10)

# %%
t=()
for i in range(5):
    t=t+(i,)
print(t)
# Out:
# (0, 1, 2, 3, 4)

# %%
lst=[]
for i in range(5):
    lst.append(i)
t=tuple(lst)
print(t)

# %%
#Repeatation
(1,2)*3
# Out:
# (1, 2, 1, 2, 1, 2)

# %%
#Membership 
4 not in (1,2,3)
# Out:
# True

# %%
#Iteration
t=(10,20,30)
for x in t:
    print(x)
# Out:
# 10
# 20
# 30

# %%
# Tuple Functions 
#Count()
#index()
t=(1,2,2,3,4)
t.count(2)
t.index(2) #1 (first occurrence)
# len(t)
# min(t) ,max(t)
# sum(t)
# Sorted(t) ----> List
# Out:
# 1

# %%
t=(5,1,2,2,3,4)
c=sorted(t)
print(c)
# Out:
# [1, 2, 2, 3, 4, 5]

# %%
t=(5,1,2,2,3,4)
tuple(sorted(t))
# Out:
# (1, 2, 2, 3, 4, 5)

# %%
t=(10,20,30)
a,b,c=t

# %%
a
# Out:
# 10

# %%
b
# Out:
# 20

# %%
c
# Out:
# 30

# %%
a,b=(1,2,3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 a,b=(1,2,3)
#
# ValueError: too many values to unpack (expected 2, got 3)

# %%
# Multiple return values ()

def parse_record(row):
    user_id=row["user_id"]
    city=row["city"]
    action=row["action"]
    return user_id,city,action

# %%
uid,city,action=parse_record({"user_id":"20","city":"Mumbai","action":"view"})

# %%
uid
# Out:
# '20'

# %%
city
# Out:
# 'Mumbai'

# %%
action
# Out:
# 'view'

# %%
records=[("Amit",30),("Neha",25),("Ravi",45)]
for name,age in records:
   print(name,age)
# Out:
# Amit 30
# Neha 25
# Ravi 45

# %%
nums=(1,2,3,4,5)
first,*rest=nums
print(first)
print(rest)
#*rest grabs everything except what’s already assigned, and stores it in a list.
# Out:
# 1
# [2, 3, 4, 5]

# %% [markdown]
# # Find Common element Between Two Tuples (Order is Matters)
# t1=(1,2,3,4,5)
# t2=(3,5,7,9)
#
# # Split tuple into Even & Odd
# t=(1,2,3,4,5,6,7)
# even= (2,4,6)
# odd=(1,3,5,7)
#
# # Count Frequency of each Element
# t=(1,2,2,3,3,3,4)
#
# output
# {1:1,2:2,3:3,4:1}
#
# # Remove All Occurences of an element
# nums=[1,2,3,2,4,2,5]
#
# Output - [1,2,3,4]
#
# #----------Imp-----------#
# # Merge Two sorted tuple into one sorted tuple
# t1=(1,3,5,7)
# t2=(2,4,6,8)
#
# Output -- (1,2,3,4,5,6,7,8)
#
# # Fallten Nested List
#
# lst=[1,[2,[3,4],5],6]
# ----> [1,2,3,4,5,6]
#
# Hint:
#     Recursion
#     Type Checking
