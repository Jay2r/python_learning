# %%
t=(10,20,30)
print(type(t))
# Out:
# <class 'tuple'>

# %%
t=10,20,30
print(type(t))
# Out:
# <class 'tuple'>

# %%
t1=(3,)
t2=(5)
print(type(t1))
print(type(t2))
# Out:
# <class 'tuple'>
# <class 'int'>

# %%
c=tuple([1,2,3,4])
print(type(c))
print(c)
# Out:
# <class 'tuple'>
# (1, 2, 3, 4)

# %%
t=(1,(5,6),4)
print(t[1])
print(t[1][0])
# Out:
# (5, 6)
# 5

# %%
'''t=[1,2,3]
t[1].append(3)''' #t[1] is an int so cant append
t=[3,4,5,[6,7]]
t[3].append(8)
print(t)
# Out:
# [3, 4, 5, [6, 7, 8]]

# %%
t=(1,[10,20],3)
t[1].append(30)
print(t)
# Out:
# (1, [10, 20, 30], 3)

# %%
# Tuple Operations 
#Concatenation 
(1,2)+(3,4)   #concatenation always createsa  new object

# %%
t=(1,2,4,3,1)
b=sorted(t)
print(b)
print(t)
# Out:
# [1, 1, 2, 3, 4]
# (1, 2, 4, 3, 1)

# %%
t=(10,20,30)
a,b,c=t
d,e=(40,50)
print(a,b,c)
print(d,e)
# Out:
# 10 20 30
# 40 50

# %%
def parse_record(x):
    user_id=x["user_id"]
    city=x["city"]
    action=x["action"]
    return user_id,city,action

# %%
uid,city,action=parse_record({"user_id":"20","city":"Mumbai","action":"view"})

# %%
uid
# Out:
# '20'

# %%
city
# Out:
# 'Mumbai'

# %%
action
# Out:
# 'view'

# %%
records=[("Amit",30),("Neha",25),("Ravi",45)]
for name,age in records:
   print(name,age)
# Out:
# Amit 30
# Neha 25
# Ravi 45

# %%
nums=(1,2,3,4,5)
first,*rest=nums
print(type(first))
print(type(rest))
# Out:
# <class 'int'>
# <class 'list'>
