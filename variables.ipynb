# %%
name = "vijay"    #it dynamically takes string no need to specify
name = "jay"
age = 25
salary = 35000.678
print(name)
print(age)
print(salary)
# Out:
# jay
# 25
# 35000.678

# %%
print(type(name)) #to find the type of name (each cell is connected)
print(type(age))
print(type(salary))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>

# %%
a=b=c=10  #assign same value to multiple variables
print(a,b,c)
# Out:
# 10 10 10

# %%
a,b,c = 10,20,40 #assign different values in one line
print(a,b,c)
# Out:
# 10 20 40

# %%
print(a,b,c) #it will show result of recently executed cell
# Out:
# 10 10 10

# %%
a = 10   
a= "dtrig"   #swap variables no need of temp
b = 5

a, b = b, a
print("a=", a,"b=",b)
# Out:
# a= 5 b= dtrig

# %%
PI = 3.14159     #constants are always written in uppercase
MAX_LIMIT = 100
