# %%
s="hello" #immutable
s[0]="H"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 s="hello" #immutable
# ----> 2 s[0]="H"
#
# TypeError: 'str' object does not support item assignment

# %%
msg="""hello
pythom
hi
java"""
print(msg)
# Out:
# hello
# pythom
# hi
# java

# %%
print("hello\npython\nhi\njava")
# Out:
# hello
# python
# hi
# java

# %%
s="PYTHONPROGRAMMING"
print(s[::2])
# Out:
# PTOPORMIG

# %%
print(s[::-2])
# Out:
# GIMROPOTP

# %%
print(s[3:10:-1])

# %%
print(s[-5:-1])
# Out:
# MMIN

# %%
"data engineering course".title()
# Out:
# 'Data Engineering Course'

# %%
"I love Java".replace("Java","Python")
# Out:
# 'I love Python'

# %%
"a,b,c".split(",")
# Out:
# ['a', 'b', 'c']

# %%
"Hello    Spark".split()
# Out:
# ['Hello', 'Spark']

# %%
"a,b,c".rsplit(",",1)  #right split 1 means only one time
# Out:
# ['a,b', 'c']

# %%
"Hello\nPython".splitlines()
# Out:
# ['Hello', 'Python']

# %%
"Hello {}".format("Python")
# Out:
# 'Hello Python'

# %%
a="data"
b="engineering"
"{} {}".format(a,b)
# Out:
# 'data engineering'

# %%
"python".startswith("Py")
# Out:
# False

# %%
"file.csv".endswith(".csv")
# Out:
# True

# %%
log= "ERROR|2026-02-16|Timeout occured"

parts=log.split("|")

# %%
parts
# Out:
# ['ERROR', '2026-02-16', 'Timeout occured']

# %%
level=parts[0]
data=parts[1]
msg=parts[2]

# %%
level
# Out:
# 'ERROR'

# %%
file_name="data_2026.sv"

if file_name.endswith(".csv"):
    print("Process file")
elif file_name.endswith(".sv"):
    print("File is not CSV")
# Out:
# File is not CSV
